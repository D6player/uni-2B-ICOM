# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# -3dB - 10kHz
# -5dB - 12.857 kHz
# -10dB - 18.214 kHz
# -20dB - 25.714 kHz
# -30dB - 31.548 kHz
# -60dB - 50 kHz

# %%
x = [-3, -5, -10, -20, -30, -50]
y = [10, 12.857, 18.214, 25.714, 31.548, 40]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.invert_xaxis()
ax.plot(x, y, marker="o")
#ax.plot(x, [9.5*np.log(-i) for i in x])
#ax.plot(x, [38*(1-np.e**(i/16.7)) for i in x])
ax.grid()
ax.minorticks_on()
ax.grid(True, which="minor", axis="y", linestyle="--")
ax.set_xlabel("Desnivell de potència [dB]")
ax.set_ylabel("Amplada de banda [kHz]")
plt.savefig("fotos/p3_2.pdf", bbox_inches="tight")
# Out:
# Text(0, 0.5, 'Amplada de banda [kHz]')
